# %% [markdown]
# <a href="https://colab.research.google.com/github/caesar013/PCVK_GENAP_2023/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow #for image display
from skimage import io
from skimage import transform
from PIL import Image, ImageDraw as id
import matplotlib.pylab as plt

# %%
# Membuat list untuk menyimpan URL dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg","https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg","https://placekitten.com/800/571"]
# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan dalam list
for url in urls :
  image = io.imread(url)                          #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) #resize image to half its size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)  #convert color to RGB
  final_frame = cv.hconcat((image, image_2))      #concentanate image
  cv2_imshow(final_frame)                         #show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print('Resolusi image: tinggi x lebar = ', tinggi, ' x ', lebar)
cv2_imshow(image_2)
# Out:
# Resolusi image: tinggi x lebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal di tengah image (horizontally)
for y in range(lebar):
  image_3[int((tinggi)/2),y] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# 1. mempermudah untuk mengenalkan kepada mahasiswa yang ingin mempelajari Python. karena di google colab sudah memiliki library yang siap untuk di "import".
# 2. berikut penjelasan dari setiap library
# - numpy adalah library yang mempermudah kita dalam mengolah array.
# - pandas adalah library yang dapat dapat kita gunakan untuk manipulasi data dan data analis.
# - cv2 adalah library untuk bagian menampilkan pada komputer
# - skimage adalah library yang membantu kita dalam pemrosesan foto di Python
# - matplotlib adalah library yang dapat membantu kita dalam pembuatan visualisasi, baik yang statik, dianimasikan, dan interaktif.
# - google.colab.patches adalah library untuk menampilkan gambar
# - PIL adalah library yang digunakan untuk pemrosesan gambar pada Python.
# 3. fungsi dari baris tersebut adalah membuat image menjadi setengah dari resolusi awal
# 4. untuk mengubah warna resolusi citra menjadi putih. karena 255,255,255 adalah kode untuk warna putih
# 5. resolusi adalah kerapatan pixel pada sebuah gambar. semakin banyak/rapat pixel yang ada pada suatu gambar, maka warna yang dihasilkan juga akan lebih terlihat berwarna.

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal di tengah image
for x in range(tinggi):
  image_3[x,int((lebar)/2)] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis diagonal 1 (dari kiri atas ke kanan bawah)
image_3 = cv.line(image_3, (0,0), (lebar, tinggi),(255,255,255),1)
# membuat garis diagonal 1 (dari kiri bawah ke kanan atas)
image_3 = cv.line(image_3, (0,tinggi), (lebar, 0),(255,255,255),1)

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal di sembarang garis
for y in range(90,290):
  image_3[157,y] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat kotak putih ditengah image (random)
for x in range(100,250):
  for y in range(190,320):
    image_3[x,y] = [255, 255, 255]


final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
img_4 = cv.imread('/content/sample_data/KTP.jpeg')
img_5 = cv.cvtColor(img_4, cv.COLOR_BGR2RGB)

img_4s = np.copy(img_4)

#tutup bagian golongan darah
for y in range (510,540):
  for x in range (165,185):
    img_4s[x,y] = [0,255,255]

#tutup bagian TTD
for y in range (595,760):
  for x in range (410,480):
    img_4s[x,y] = [0,0,255]

final_frame = cv.hconcat((img_4, img_4s))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=1600x488>
